# %%
import cv2

# %%
# vidcap = cv2.VideoCapture('fireye.mp4')
# def getFrame(sec):
#     vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
#     hasFrames,image = vidcap.read()
#     if hasFrames:
#         cv2.imwrite("fireye"+str(count)+".png", image)     # save frame as JPG file
#     return hasFrames
# sec = 0
# frameRate = 1 #//it will capture image in each 0.5 second
# count=1
# success = getFrame(sec)
# while success:
#     count = count + 1
#     sec = sec + frameRate
#     sec = round(sec, 2)
#     success = getFrame(sec)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
Benign_Websites = pd.read_excel('capturedMine.xlsx', sheet_name='Benign Websites')
Malicious = pd.read_excel('capturedMine.xlsx', sheet_name='Malicious')
SafeWebsite = pd.read_excel('capturedMine.xlsx', sheet_name='SafeWebsite')
time = np.arange(60)+1

# %%
MaliciousData = Malicious.values.T[1:,:]
labels = Malicious.columns[1:]
MaliciousData.shape, time.shape
# Out:
# ((5, 60), (60,))

# %%
# width_in_inches = 20
# height_in_inches = 10
# dots_per_inch = 70
# plt.figure(
# figsize=(width_in_inches, height_in_inches),
# dpi=dots_per_inch)
# for i in range(5):
#     plt.plot(time, MaliciousData[i], label=labels[i])
# #plt.plot(np.mean(Data, axis=0), label="Mean", color='blue')
# #plt.xticks(np.arange(47), DatasetTB1.columns, rotation='vertical', fontsize=20)
# plt.grid(True)
# # Tweak spacing to prevent clipping of tick-labels
# plt.subplots_adjust(bottom=0.15)
# plt.xlabel('Time in seconds ', fontsize=20)
# plt.ylabel('Browser CPU consumption', fontsize=20)
# plt.title('Plot for malicious', fontsize=20)
# # show a legend on the plot
# plt.legend(fontsize=15)
# # Display a figure.
# plt.show()
# print("******")

# %%
keywords = pd.read_csv('keyword.csv')
pages = pd.read_csv('pages.csv')
processed_keywords = keywords.values
processed_pages = pages.values
processed_keywords
# Out:
# array([['CoinHive'],
#        ['miner_webs '],
#        ['jsecoin'],
#        ['miner'],
#        ['cpu'],
#        ['WebMinerAnalyzer'],
#        ['www.coinhive.com'],
#        ['cryptoloot'],
#        ['Crypto-Loot'],
#        ['max_cpu'],
#        ['detect_cpu'],
#        ['cpu_usage'],
#        ['cpuUsage'],
#        ['blakcrypto'],
#        ['dryptonight'],
#        ['mineralt'],
#        ['minr'],
#        ['cpufun'],
#        ['minescripts'],
#        ['grindcash'],
#        ['coincube'],
#        ['monerise'],
#        ['deepminer'],
#        ['cryptonoter'],
#        ['bitcoin.com'],
#        ['coinimp'],
#        ['CoinImp'],
#        ['JSECoin'],
#        ['Miner(elements[i])'],
#        ['HushMiner'],
#        ['YAZECMiner'],
#        ['NFWebMiner'],
#        ['Obfuscated'],
#        ['cpu'],
#        ['coin '],
#        ['kill_chromium'],
#        ['start_chromium'],
#        ['blakcrypto'],
#        ['dryptonight'],
#        ['coinhave'],
#        ['coinhive'],
# ...

# %%
from html.parser import HTMLParser
from html.entities import name2codepoint
#pattern = re.compile('throttle')
#pattern.search(soup)

# %%
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs, pattern):
        for attr in attrs:
            if pattern.search(str(attr)):
                print("Match :", pattern.search(str(attr)))
    def handle_endtag(self, tag):
        pass
    def handle_data(self, data, pattern):
        if pattern.search(data):
            print("Match :", pattern.search(data))
parser = MyHTMLParser()

# %%
parser.feed('<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" ''"http://www.w3.org/TR/html4/strict.dtd">')

# %%
# parser.feed('<script type="text/javascript">''alert("<strong>hello!</strong>");</script>')

# %%
 

from bs4 import BeautifulSoup
import re

for page in processed_pages:
    print('From our web page called ', page[0])
    with open(page[0]) as fp:
        soup = BeautifulSoup(fp, "lxml")
        for keyword in processed_keywords:
            pattern = re.compile(keyword[0])

            parser.feed(str(soup))
            if pattern.search(str(soup.a)):
                print("Match :",pattern.search(str(soup.a)))
    print(" ")
# Out:
# From our web page called  awf.html
#
# From our web page called  bestway.html
# Match : <_sre.SRE_Match object; span=(12, 15), match='cpu'>
# Match : <_sre.SRE_Match object; span=(46, 49), match='cpu'>
# Match : <_sre.SRE_Match object; span=(25, 36), match='bitcoin.com'>
# Match : <_sre.SRE_Match object; span=(24, 35), match='bitcoin.com'>
# Match : <_sre.SRE_Match object; span=(12, 15), match='cpu'>
# Match : <_sre.SRE_Match object; span=(46, 49), match='cpu'>
# Match : <_sre.SRE_Match object; span=(21, 26), match='coin '>
# Match : <_sre.SRE_Match object; span=(56, 61), match='coin '>
# Match : <_sre.SRE_Match object; span=(21, 26), match='coin '>
# Match : <_sre.SRE_Match object; span=(31, 36), match='coin '>
# Match : <_sre.SRE_Match object; span=(3, 8), match='coin '>
# Match : <_sre.SRE_Match object; span=(30, 36), match='monero'>
# Match : <_sre.SRE_Match object; span=(52, 56), match='hash'>
# Match : <_sre.SRE_Match object; span=(102, 106), match='hash'>
# ...

# %%
tag = soup.script

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.wp-monero-miner.com/xmlrpc.php" rel="pingback"/>
# <title>WP Monero Miner – Let your users mine for you!</title>
# </head><body><br/>
# <b>Warning</b>:  file_get_contents(): php_network_getaddresses: getaddrinfo failed: Name or service not known in <b>/home/wpmonero/public_html/wp-monero-miner/wordpress/wp-content/plugins/wp-monero-miner/services/api-service.php</b> on line <b>33</b><br/>
# <br/>
# <b>Warning</b>:  file_get_contents(https://api.coinhive.com/user/top?secret=8gyYHq9At2KIYA6TKNyq8DZtBneansfl): failed to open stream: php_network_getaddresses: getaddrinfo failed: Name or service not known in <b>/home/wpmonero/public_html/wp-monero-miner/wordpress/wp-content/plugins/wp-monero-miner/services/api-service.php</b> on line <b>33</b><br/>
# ...

# %%
pattern = re.compile('b')
pattern.search(soup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-29b961a7f12a> in <module>()
#       1 pattern = re.compile('b')
# ----> 2 pattern.search(soup)
#
# TypeError: expected string or bytes-like object

# %%
for tag in soup.find_all(re.compile("^b")):
    print(tag.name)
# Out:
# body

# %%
for tag in soup.find_all(id='hidden'):
    print(tag.name)

# %%
for chunk in ['<sp', 'an>buff', 'ered ', 'text</s', 'pan>']:
...     parser.feed(chunk)
